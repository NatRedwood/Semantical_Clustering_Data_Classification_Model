# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import importlib, import_ipynb
import data_clean_order as data
import tensorflow as tf
from tensorflow.data import experimental
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split, cross_val_score
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# model building imports
from keras.layers import Embedding, Flatten, Dense, Dropout
from keras.layers import Conv1D, SimpleRNN, Bidirectional, MaxPooling1D, GlobalMaxPool1D, LSTM, GRU
from keras.models import Sequential
from keras.regularizers import L1L2

# %matplotlib inline

# matplotlib defaults
plt.style.use("ggplot")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

import warnings 
warnings.filterwarnings('ignore')

# %%
# %store -r ordered_super_alpha_text
# %store -r ordered_class_alpha_text
# %store -r ordered_sem_clusters_desc_text
# %store -r ordered_sem_clusters_asc_text
# %store -r ordered_sem_clusters_shuffled_per_superclass_text
# %store -r test_df

# %%
# Experimental data orderings on headlines TRAIN EXAMPLES
X1_train = ordered_super_alpha_text['cleaned_headline']
X2_train = ordered_class_alpha_text['cleaned_headline']
X3_train = ordered_sem_clusters_desc_text['cleaned_headline']
X4_train = ordered_sem_clusters_asc_text['cleaned_headline']
X5_train = ordered_sem_clusters_shuffled_per_superclass_text['cleaned_headline']

# Experimental data orderings on short_description #TODO

# TRAIN LABELS
Y1_train = ordered_super_alpha_text['superclass']
Y2_train = ordered_class_alpha_text['superclass']
Y3_train = ordered_sem_clusters_desc_text['superclass']
Y4_train = ordered_sem_clusters_asc_text['superclass']
Y5_train = ordered_sem_clusters_shuffled_per_superclass_text['superclass']

# TEST EXAMPLES
X_test = test_df['cleaned_headline']
Y_test = test_df['superclass']

# %% [markdown]
# ## Tokenization and Vectorization

# %% [markdown]
# ### One-hot encoding and indexing of train and test data

# %%
# TEST DATA

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_test = encoder.fit_transform(Y_test)
print("shape of input data: ", X_test.shape)
print("shape of target variable: ", Y_test.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_test) # build the word index
# padding X_test text input data
test_seq = tokenizer.texts_to_sequences(X_test) # converts strinfs into integer lists
test_padseq = pad_sequences(test_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 150000000  # total number of words to consider in embedding layer
total_words = len(word_index)
maxlen = 20 # max length of sequence 
Y_test = to_categorical(Y_test, num_classes=9)
print("Length of word index:", total_words)
# Out:
# shape of input data:  (41905,)
# shape of target variable:  (41905,)
# Length of word index: 27262

# %% [markdown]
# # EXPERIMENT ORDER 1

# %%
# ORDER 1 TRAIN DATA
X_train = X1_train
Y_train = Y1_train

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("shape of input data: ", X_train.shape)
print("shape of target variable: ", Y_train.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_train) # build the word index
# padding X_train text input data
train_seq = tokenizer.texts_to_sequences(X_train) # converts strinfs into integer lists
train_padseq = pad_sequences(train_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 15000000  # total number of words to consider in embedding layer
total_words = len(word_index) + 1000
maxlen = 20 # max length of sequence 
Y_train = to_categorical(Y_train, num_classes=9)
print("Length of word index:", total_words)
# Out:
# shape of input data:  (167616,)
# shape of target variable:  (167616,)
# Length of word index: 53645

# %% [markdown]
# ### Model 2, training using Conv1D, Bi-directional RNN, LSTMs and GRU layer

# %%
model2 = Sequential()
model2.add(Embedding(total_words, 100, input_length=maxlen))
model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Conv1D(72, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(SimpleRNN(64, activation='tanh', dropout=0.2, recurrent_dropout=0.20, return_sequences=True))
model2.add(GRU(64, recurrent_dropout=0.20, recurrent_regularizer='l1_l2'))
model2.add(Dropout(0.2))
model2.add(Dense(9, activation='softmax'))
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 100)           5364500
#
#  bidirectional (Bidirectiona  (None, 20, 128)          84480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 20, 128)          98816
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 20, 128)          24704
#  nal)
#
#  conv1d (Conv1D)             (None, 18, 72)            27720
#
#  max_pooling1d (MaxPooling1D  (None, 9, 72)            0
#  )
#
#  simple_rnn_1 (SimpleRNN)    (None, 9, 64)             8768
#
#  gru (GRU)                   (None, 64)                24960
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 9)                 585
#
# =================================================================
# Total params: 5,634,533
# Trainable params: 5,634,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# SETUP A EARLY STOPPING CALL and model check point API
earlystopping = keras.callbacks.EarlyStopping(monitor='accuracy',
                                              patience=5,
                                              verbose=1,
                                              mode='min'
                                              )
checkpointer = ModelCheckpoint(filepath='bestvalue1',moniter='val_loss', verbose=0, save_best_only=True)
callback_list = [checkpointer, earlystopping]

# fit model to the data
history2 = model2.fit(train_padseq, Y_train, 
                     batch_size=128, 
                     epochs=15
                    )

# evalute the model
test_loss2, test_acc2 = model2.evaluate(test_padseq, Y_test, verbose=0)
print("test loss and accuracy:", test_loss2, test_acc2)
# Out:
# Epoch 1/15
# 1310/1310 [==============================] - 384s 263ms/step - loss: 1.6671 - accuracy: 0.5452
# Epoch 2/15
# 1310/1310 [==============================] - 309s 236ms/step - loss: 1.1044 - accuracy: 0.6694
# Epoch 3/15
# 1310/1310 [==============================] - 310s 236ms/step - loss: 1.0005 - accuracy: 0.7041
# Epoch 4/15
# 1310/1310 [==============================] - 301s 230ms/step - loss: 0.9293 - accuracy: 0.7279
# Epoch 5/15
# 1310/1310 [==============================] - 303s 231ms/step - loss: 0.8714 - accuracy: 0.7470
# Epoch 6/15
# 1310/1310 [==============================] - 317s 242ms/step - loss: 0.8183 - accuracy: 0.7638
# Epoch 7/15
# 1310/1310 [==============================] - 331s 253ms/step - loss: 0.7736 - accuracy: 0.7801
# Epoch 8/15
# 1310/1310 [==============================] - 350s 267ms/step - loss: 0.7349 - accuracy: 0.7930
# Epoch 9/15
# 1310/1310 [==============================] - 346s 264ms/step - loss: 0.7009 - accuracy: 0.8040
# Epoch 10/15
# 1310/1310 [==============================] - 344s 263ms/step - loss: 0.6727 - accuracy: 0.8138
# Epoch 11/15
# 1310/1310 [==============================] - 352s 269ms/step - loss: 0.6484 - accuracy: 0.8220
# Epoch 12/15
# 1310/1310 [==============================] - 349s 266ms/step - loss: 0.6258 - accuracy: 0.8281
# Epoch 13/15
# 1310/1310 [==============================] - 346s 264ms/step - loss: 0.6060 - accuracy: 0.8351
# Epoch 14/15
# 1310/1310 [==============================] - 352s 269ms/step - loss: 0.5909 - accuracy: 0.8403
# Epoch 15/15
# 1310/1310 [==============================] - 345s 263ms/step - loss: 0.5737 - accuracy: 0.8458
# test loss and accuracy: 3.310349702835083 0.20186135172843933

# %%
def plot_loss_accuracy(history):

    # create object of arrays of accuracy and loss
    acc = history.history['accuracy']
    #val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    #val_loss = history.history['val_loss']
    
    # number of epochs in our model
    epochs = range(1 ,len(acc) + 1)
    
    # call matplolib figure object and plot loss and accuracy curves
    plt.figure(figsize=(15,6))
    
    plt.subplot(121)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    #plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title("Training accuracy", fontsize=15)
    plt.xlabel('epochs', fontsize=14)
    plt.ylabel("accuracy", fontsize=14)
    plt.legend()
    
    plt.subplot(122)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    #plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title("Training loss", fontsize=15)
    plt.xlabel('epochs', fontsize=14)
    plt.ylabel("loss", fontsize=14)
    plt.legend()
    
    plt.show()

# %%
plot_loss_accuracy(history2)

# %% [markdown]
# # EXPERIMENT ORDER 2

# %%
# ORDER 2 TRAIN DATA
X_train = X2_train
Y_train = Y2_train

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("shape of input data: ", X_train.shape)
print("shape of target variable: ", Y_train.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_train) # build the word index
# padding X_train text input data
train_seq = tokenizer.texts_to_sequences(X_train) # converts strinfs into integer lists
train_padseq = pad_sequences(train_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 15000000  # total number of words to consider in embedding layer
total_words = len(word_index) + 1000
maxlen = 20 # max length of sequence 
Y_train = to_categorical(Y_train, num_classes=9)
print("Length of word index:", total_words)
# Out:
# shape of input data:  (167616,)
# shape of target variable:  (167616,)
# Length of word index: 53645

# %% [markdown]
# ### Model 2, training using Conv1D, Bi-directional RNN, LSTMs and GRU layer

# %%
model2 = Sequential()
model2.add(Embedding(total_words, 100, input_length=maxlen))
model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Conv1D(72, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(SimpleRNN(64, activation='tanh', dropout=0.2, recurrent_dropout=0.20, return_sequences=True))
model2.add(GRU(64, recurrent_dropout=0.20, recurrent_regularizer='l1_l2'))
model2.add(Dropout(0.2))
model2.add(Dense(9, activation='softmax'))
model2.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\CU BOULDER\CSCI5922_NN\FinalProject\Semantical_Clustering_Data_Classification_Model\scripts\models_model2_headlines_superclassesOK.ipynb Cell 17 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> model2.add(Embedding(total_words, 100, input_length=maxlen))
#       <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
# ----> <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
#       <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
#       <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> model2.add(Conv1D(72, 3, activation='relu'))
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py:530, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     528 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529 try:
# --> 530   result = method(self, *args, **kwargs)
#     531 finally:
#     532   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\sequential.py:220, in Sequential.add(self, layer)
#     215     self._has_explicit_input_shape = True
#     217 elif self.outputs:
#     218   # If the model is being built continuously on top of an input layer:
#     219   # refresh its output.
# --> 220   output_tensor = layer(self.outputs[0])
#     221   if len(tf.nest.flatten(output_tensor)) != 1:
#     222     raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\layers\wrappers.py:586, in Bidirectional.__call__(self, inputs, initial_state, constants, **kwargs)
#     583   inputs = inputs[0]
#     585 if initial_state is None and constants is None:
# --> 586   return super(Bidirectional, self).__call__(inputs, **kwargs)
#     588 # Applies the same workaround as in `RNN.__call__`
#     589 additional_inputs = []
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\base_layer.py:1019, in Layer.__call__(self, *args, **kwargs)
#    1013 # Functional Model construction mode is invoked when `Layer`s are called on
#    1014 # symbolic `KerasTensor`s, i.e.:
#    1015 # >> inputs = tf.keras.Input(10)
#    1016 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1017 # >> model = tf.keras.Model(inputs, outputs)
#    1018 if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# -> 1019   return self._functional_construction_call(inputs, args, kwargs,
#    1020                                             input_list)
#    1022 # Maintains info about the `Layer.call` stack.
#    1023 call_context = base_layer_utils.call_context()
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\base_layer.py:1160, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    1155     training_arg_passed_by_framework = True
#    1157 with call_context.enter(
#    1158     layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1159   # Check input assumptions set after layer building, e.g. input shape.
# -> 1160   outputs = self._keras_tensor_symbolic_call(
#    1161       inputs, input_masks, args, kwargs)
#    1163   if outputs is None:
#    1164     raise ValueError('A layer\'s `call` method should return a '
#    1165                      'Tensor or a list of Tensors, not None '
#    1166                      '(layer: ' + self.name + ').')
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\base_layer.py:885, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     883   return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     884 else:
# --> 885   return self._infer_output_signature(inputs, args, kwargs, input_masks)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\base_layer.py:930, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#     928     self._maybe_build(inputs)
#     929     inputs = self._maybe_cast_inputs(inputs)
# --> 930     outputs = call_fn(inputs, *args, **kwargs)
#     932   self._handle_activity_regularization(inputs, outputs)
#     933 self._set_mask_metadata(inputs, outputs, input_masks,
#     934                         build_graph=False)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\layers\wrappers.py:701, in Bidirectional.call(self, inputs, training, mask, initial_state, constants)
#     698     forward_inputs, backward_inputs = inputs, inputs
#     699     forward_state, backward_state = None, None
# --> 701   y = self.forward_layer(forward_inputs,
#     702                          initial_state=forward_state, **kwargs)
#     703   y_rev = self.backward_layer(backward_inputs,
#     704                               initial_state=backward_state, **kwargs)
#     705 else:
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\layers\recurrent.py:679, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     673 inputs, initial_state, constants = _standardize_args(inputs,
#     674                                                      initial_state,
#     675                                                      constants,
#     676                                                      self._num_constants)
#     678 if initial_state is None and constants is None:
# --> 679   return super(RNN, self).__call__(inputs, **kwargs)
#     681 # If any of `initial_state` or `constants` are specified and are Keras
#     682 # tensors, then add them to the inputs and temporarily modify the
#     683 # input_spec to include them.
#     685 additional_inputs = []
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\engine\base_layer.py:1083, in Layer.__call__(self, *args, **kwargs)
#    1079   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1081 with autocast_variable.enable_auto_cast_variables(
#    1082     self._compute_dtype_object):
# -> 1083   outputs = call_fn(inputs, *args, **kwargs)
#    1085 if self._activity_regularizer:
#    1086   self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\layers\recurrent_v2.py:1158, in LSTM.call(self, inputs, mask, training, initial_state)
#    1155   def step(inputs, states):
#    1156     return self.cell(inputs, states, **kwargs)
# -> 1158   last_output, outputs, states = backend.rnn(
#    1159       step,
#    1160       inputs,
#    1161       initial_state,
#    1162       constants=None,
#    1163       go_backwards=self.go_backwards,
#    1164       mask=mask,
#    1165       unroll=self.unroll,
#    1166       input_length=row_lengths if row_lengths is not None else timesteps,
#    1167       time_major=self.time_major,
#    1168       zero_output_for_mask=self.zero_output_for_mask)
#    1169   runtime = _runtime(_RUNTIME_UNKNOWN)
#    1170 else:
#    1171   # Use the new defun approach for backend implementation swap.
#    1172   # Note that different implementations need to have same function
#    1173   # signature, eg, the tensor parameters need to have same shape and dtypes.
#    1174   # Since the cuDNN has an extra set of bias, those bias will be passed to
#    1175   # both normal and cuDNN implementations.
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1096, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1094 # Fallback dispatch system (dispatch v1):
#    1095 try:
# -> 1096   return dispatch_target(*args, **kwargs)
#    1097 except (TypeError, ValueError):
#    1098   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1099   # TypeError, when given unexpected types.  So we need to catch both.
#    1100   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\backend.py:4491, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4486 states = tuple(initial_states)
#    4488 # Create input tensor array, if the inputs is nested tensors, then it will
#    4489 # be flattened first, and tensor array will be created one per flattened
#    4490 # tensor.
# -> 4491 input_ta = tuple(
#    4492     tf.TensorArray(
#    4493         dtype=inp.dtype,
#    4494         size=time_steps_t,
#    4495         tensor_array_name='input_ta_%s' % i)
#    4496     for i, inp in enumerate(flatted_inputs))
#    4497 input_ta = tuple(
#    4498     ta.unstack(input_) if not go_backwards else ta
#    4499     .unstack(reverse(input_, 0))
#    4500     for ta, input_ in zip(input_ta, flatted_inputs))
#    4502 # Get the time(0) input and compute the output for that, the output will be
#    4503 # used to determine the dtype of output tensor array. Don't read from
#    4504 # input_ta due to TensorArray clear_after_read default to True.
#
# File c:\Users\natal\anaconda3\lib\site-packages\keras\backend.py:4492, in <genexpr>(.0)
#    4486 states = tuple(initial_states)
#    4488 # Create input tensor array, if the inputs is nested tensors, then it will
#    4489 # be flattened first, and tensor array will be created one per flattened
#    4490 # tensor.
#    4491 input_ta = tuple(
# -> 4492     tf.TensorArray(
#    4493         dtype=inp.dtype,
#    4494         size=time_steps_t,
#    4495         tensor_array_name='input_ta_%s' % i)
#    4496     for i, inp in enumerate(flatted_inputs))
#    4497 input_ta = tuple(
#    4498     ta.unstack(input_) if not go_backwards else ta
#    4499     .unstack(reverse(input_, 0))
#    4500     for ta, input_ in zip(input_ta, flatted_inputs))
#    4502 # Get the time(0) input and compute the output for that, the output will be
#    4503 # used to determine the dtype of output tensor array. Don't read from
#    4504 # input_ta due to TensorArray clear_after_read default to True.
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py:1082, in TensorArray.__init__(self, dtype, size, dynamic_size, clear_after_read, tensor_array_name, handle, flow, infer_shape, element_shape, colocate_with_first_write_call, name)
#    1080 else:
#    1081   implementation = _GraphTensorArray
# -> 1082 self._implementation = implementation(
#    1083     dtype,
#    1084     size=size,
#    1085     dynamic_size=dynamic_size,
#    1086     clear_after_read=clear_after_read,
#    1087     tensor_array_name=tensor_array_name,
#    1088     handle=handle,
#    1089     flow=flow,
#    1090     infer_shape=infer_shape,
#    1091     element_shape=element_shape,
#    1092     colocate_with_first_write_call=colocate_with_first_write_call,
#    1093     name=name)
#    1095 self._implementation.parent = weakref.ref(self)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\ops\tensor_array_ops.py:475, in _GraphTensorArrayV2.__init__(***failed resolving arguments***)
#     473 with ops.name_scope(name, "TensorArrayV2", [size, flow]) as scope:
#     474   if flow is None:
# --> 475     self._flow = list_ops.tensor_list_reserve(
#     476         element_shape=element_shape,
#     477         num_elements=size,
#     478         element_dtype=dtype,
#     479         name=scope)
#     480   else:
#     481     self._flow = flow
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\ops\list_ops.py:86, in tensor_list_reserve(element_shape, num_elements, element_dtype, name)
#      85 def tensor_list_reserve(element_shape, num_elements, element_dtype, name=None):
# ---> 86   result = gen_list_ops.tensor_list_reserve(
#      87       element_shape=_build_element_shape(element_shape),
#      88       num_elements=num_elements,
#      89       element_dtype=element_dtype,
#      90       name=name)
#      91   # TODO(b/169968286): gen_ops needs to ensure the metadata is properly
#      92   # populated for eager operations.
#      93   _set_handle_data(result, element_shape, element_dtype)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\ops\gen_list_ops.py:886, in tensor_list_reserve(element_shape, num_elements, element_dtype, name)
#     884 # Add nodes to the TensorFlow graph.
#     885 element_dtype = _execute.make_type(element_dtype, "element_dtype")
# --> 886 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     887       "TensorListReserve", element_shape=element_shape,
#     888                            num_elements=num_elements,
#     889                            element_dtype=element_dtype, name=name)
#     890 _result = _outputs[:]
#     891 if _execute.must_record_gradient():
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:744, in _apply_op_helper(op_type_name, name, **keywords)
#     739 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     740                         if arg.is_ref]
#     741 with _MaybeColocateWith(must_colocate_inputs):
#     742   # Add Op to graph
#     743   # pylint: disable=protected-access
# --> 744   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     745                              name=scope, input_types=input_types,
#     746                              attrs=attr_protos, op_def=op_def)
#     748 # `outputs` is returned as a separate return value so that the output
#     749 # tensors can the `op` per se can be decoupled so that the
#     750 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     751 # for more details.
#     752 outputs = op.outputs
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:689, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     687   inp = self.capture(inp)
#     688   captured_inputs.append(inp)
# --> 689 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     691     compute_device)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3697, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3694 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3695 # Session.run call cannot occur between creating and mutating the op.
#    3696 with self._mutation_lock():
# -> 3697   ret = Operation(
#    3698       node_def,
#    3699       self,
#    3700       inputs=inputs,
#    3701       output_types=dtypes,
#    3702       control_inputs=control_inputs,
#    3703       input_types=input_types,
#    3704       original_op=self._default_original_op,
#    3705       op_def=op_def)
#    3706   self._create_op_helper(ret, compute_device=compute_device)
#    3707 return ret
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2097, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2095   if op_def is None:
#    2096     op_def = self._graph._get_op_def(node_def.op)
# -> 2097   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2098                             control_input_ops, op_def)
#    2099   name = compat.as_str(node_def.name)
#    2101 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\natal\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1909, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1907 inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#    1908 # pylint: disable=protected-access
# -> 1909 op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1910                                             compat.as_str(node_def.op),
#    1911                                             compat.as_str(node_def.name))
#    1912 if node_def.device:
#    1913   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:

# %%
model2.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# SETUP A EARLY STOPPING CALL and model check point API
earlystopping = keras.callbacks.EarlyStopping(monitor='accuracy',
                                              patience=5,
                                              verbose=1,
                                              mode='min'
                                              )
checkpointer = ModelCheckpoint(filepath='bestvalue1',moniter='val_loss', verbose=0, save_best_only=True)
callback_list = [checkpointer, earlystopping]

# fit model to the data
history2 = model2.fit(train_padseq, Y_train, 
                     batch_size=128, 
                     epochs=15
                    )

# evalute the model
test_loss2, test_acc2 = model2.evaluate(test_padseq, Y_test, verbose=0)
print("test loss and accuracy:", test_loss2, test_acc2)
# Out:
# Epoch 1/15
# 1310/1310 [==============================] - 370s 260ms/step - loss: 1.7140 - accuracy: 0.5270
# Epoch 2/15
# 1310/1310 [==============================] - 348s 266ms/step - loss: 1.1365 - accuracy: 0.6607
# Epoch 3/15
# 1310/1310 [==============================] - 341s 260ms/step - loss: 1.0115 - accuracy: 0.7009
# Epoch 4/15
# 1310/1310 [==============================] - 333s 254ms/step - loss: 0.9373 - accuracy: 0.7258
# Epoch 5/15
# 1310/1310 [==============================] - 331s 253ms/step - loss: 0.8782 - accuracy: 0.7447
# Epoch 6/15
# 1310/1310 [==============================] - 338s 258ms/step - loss: 0.8296 - accuracy: 0.7610
# Epoch 7/15
# 1310/1310 [==============================] - 336s 256ms/step - loss: 0.7845 - accuracy: 0.7773
# Epoch 8/15
# 1310/1310 [==============================] - 336s 257ms/step - loss: 0.7475 - accuracy: 0.7897
# Epoch 9/15
# 1310/1310 [==============================] - 351s 268ms/step - loss: 0.7126 - accuracy: 0.8008
# Epoch 10/15
# 1310/1310 [==============================] - 367s 280ms/step - loss: 0.6852 - accuracy: 0.8106
# Epoch 11/15
# 1310/1310 [==============================] - 354s 270ms/step - loss: 0.6597 - accuracy: 0.8186
# Epoch 12/15
# 1310/1310 [==============================] - 367s 280ms/step - loss: 0.6374 - accuracy: 0.8258
# Epoch 13/15
# 1310/1310 [==============================] - 381s 291ms/step - loss: 0.6168 - accuracy: 0.8329
# Epoch 14/15
# 1310/1310 [==============================] - 363s 277ms/step - loss: 0.5986 - accuracy: 0.8380
# Epoch 15/15
# 1310/1310 [==============================] - 339s 259ms/step - loss: 0.5837 - accuracy: 0.8433
# test loss and accuracy: 3.442798137664795 0.1953466236591339

# %%
plot_loss_accuracy(history2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\CU BOULDER\CSCI5922_NN\FinalProject\Semantical_Clustering_Data_Classification_Model\scripts\models_model2_headlines_superclassesOK.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/CU%20BOULDER/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/scripts/models_model2_headlines_superclassesOK.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> plot_loss_accuracy(history2)
#
# NameError: name 'plot_loss_accuracy' is not defined

# %% [markdown]
# # EXPERIMENT ORDER 3

# %%
# ORDER 3 TRAIN DATA
X_train = X3_train
Y_train = Y3_train

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("shape of input data: ", X_train.shape)
print("shape of target variable: ", Y_train.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_train) # build the word index
# padding X_train text input data
train_seq = tokenizer.texts_to_sequences(X_train) # converts strinfs into integer lists
train_padseq = pad_sequences(train_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 15000000  # total number of words to consider in embedding layer
total_words = len(word_index) + 1000
maxlen = 20 # max length of sequence 
Y_train = to_categorical(Y_train, num_classes=9)
print("Length of word index:", total_words)
# Out:
# shape of input data:  (167616,)
# shape of target variable:  (167616,)
# Length of word index: 53645

# %% [markdown]
# ### Model 2, training using Conv1D, Bi-directional RNN, LSTMs and GRU layer

# %%
model2 = Sequential()
model2.add(Embedding(total_words, 100, input_length=maxlen))
model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Conv1D(72, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(SimpleRNN(64, activation='tanh', dropout=0.2, recurrent_dropout=0.20, return_sequences=True))
model2.add(GRU(64, recurrent_dropout=0.20, recurrent_regularizer='l1_l2'))
model2.add(Dropout(0.2))
model2.add(Dense(9, activation='softmax'))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 20, 100)           5364500
#
#  bidirectional_5 (Bidirectio  (None, 20, 128)          84480
#  nal)
#
#  bidirectional_6 (Bidirectio  (None, 20, 128)          98816
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 20, 128)          24704
#  nal)
#
#  conv1d_1 (Conv1D)           (None, 18, 72)            27720
#
#  max_pooling1d_1 (MaxPooling  (None, 9, 72)            0
#  1D)
#
#  simple_rnn_3 (SimpleRNN)    (None, 9, 64)             8768
#
#  gru_1 (GRU)                 (None, 64)                24960
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 5,634,533
# Trainable params: 5,634,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# SETUP A EARLY STOPPING CALL and model check point API
earlystopping = keras.callbacks.EarlyStopping(monitor='accuracy',
                                              patience=5,
                                              verbose=1,
                                              mode='min'
                                              )
checkpointer = ModelCheckpoint(filepath='bestvalue1',moniter='val_loss', verbose=0, save_best_only=True)
callback_list = [checkpointer, earlystopping]

# fit model to the data
history2 = model2.fit(train_padseq, Y_train, 
                     batch_size=128, 
                     epochs=15
                    )

# evalute the model
test_loss2, test_acc2 = model2.evaluate(test_padseq, Y_test, verbose=0)
print("test loss and accuracy:", test_loss2, test_acc2)
# Out:
# Epoch 1/15
# 1310/1310 [==============================] - 367s 260ms/step - loss: 1.7189 - accuracy: 0.5256
# Epoch 2/15
# 1310/1310 [==============================] - 336s 257ms/step - loss: 1.1329 - accuracy: 0.6606
# Epoch 3/15
# 1310/1310 [==============================] - 332s 253ms/step - loss: 1.0089 - accuracy: 0.7002
# Epoch 4/15
# 1310/1310 [==============================] - 366s 279ms/step - loss: 0.9376 - accuracy: 0.7250
# Epoch 5/15
# 1310/1310 [==============================] - 340s 260ms/step - loss: 0.8816 - accuracy: 0.7434
# Epoch 6/15
# 1310/1310 [==============================] - 352s 269ms/step - loss: 0.8314 - accuracy: 0.7610
# Epoch 7/15
# 1310/1310 [==============================] - 343s 262ms/step - loss: 0.7882 - accuracy: 0.7753
# Epoch 8/15
# 1310/1310 [==============================] - 337s 257ms/step - loss: 0.7492 - accuracy: 0.7888
# Epoch 9/15
# 1310/1310 [==============================] - 339s 259ms/step - loss: 0.7171 - accuracy: 0.8002
# Epoch 10/15
# 1310/1310 [==============================] - 339s 259ms/step - loss: 0.6901 - accuracy: 0.8083
# Epoch 11/15
# 1310/1310 [==============================] - 342s 261ms/step - loss: 0.6629 - accuracy: 0.8173
# Epoch 12/15
# 1310/1310 [==============================] - 339s 259ms/step - loss: 0.6419 - accuracy: 0.8248
# Epoch 13/15
# 1310/1310 [==============================] - 350s 267ms/step - loss: 0.6251 - accuracy: 0.8302
# Epoch 14/15
# 1310/1310 [==============================] - 360s 275ms/step - loss: 0.6083 - accuracy: 0.8349
# Epoch 15/15
# 1310/1310 [==============================] - 366s 280ms/step - loss: 0.5933 - accuracy: 0.8396
# test loss and accuracy: 3.3404884338378906 0.19038300216197968

# %%
plot_loss_accuracy(history2)

# %% [markdown]
# # EXPERIMENT ORDER 4

# %%
# ORDER 4 TRAIN DATA
X_train = X4_train
Y_train = Y4_train

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("shape of input data: ", X_train.shape)
print("shape of target variable: ", Y_train.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_train) # build the word index
# padding X_train text input data
train_seq = tokenizer.texts_to_sequences(X_train) # converts strinfs into integer lists
train_padseq = pad_sequences(train_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 15000000  # total number of words to consider in embedding layer
total_words = len(word_index) + 1000
maxlen = 20 # max length of sequence 
Y_train = to_categorical(Y_train, num_classes=9)
print("Length of word index:", total_words)
# Out:
# shape of input data:  (167616,)
# shape of target variable:  (167616,)
# Length of word index: 53645

# %% [markdown]
# ### Model 2, training using Conv1D, Bi-directional RNN, LSTMs and GRU layer

# %%
model2 = Sequential()
model2.add(Embedding(total_words, 100, input_length=maxlen))
model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Conv1D(72, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(SimpleRNN(64, activation='tanh', dropout=0.2, recurrent_dropout=0.20, return_sequences=True))
model2.add(GRU(64, recurrent_dropout=0.20, recurrent_regularizer='l1_l2'))
model2.add(Dropout(0.2))
model2.add(Dense(9, activation='softmax'))
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 20, 100)           5364500
#
#  bidirectional_8 (Bidirectio  (None, 20, 128)          84480
#  nal)
#
#  bidirectional_9 (Bidirectio  (None, 20, 128)          98816
#  nal)
#
#  bidirectional_10 (Bidirecti  (None, 20, 128)          24704
#  onal)
#
#  conv1d_2 (Conv1D)           (None, 18, 72)            27720
#
#  max_pooling1d_2 (MaxPooling  (None, 9, 72)            0
#  1D)
#
#  simple_rnn_5 (SimpleRNN)    (None, 9, 64)             8768
#
#  gru_2 (GRU)                 (None, 64)                24960
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 5,634,533
# Trainable params: 5,634,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# SETUP A EARLY STOPPING CALL and model check point API
earlystopping = keras.callbacks.EarlyStopping(monitor='accuracy',
                                              patience=5,
                                              verbose=1,
                                              mode='min'
                                              )
checkpointer = ModelCheckpoint(filepath='bestvalue1',moniter='val_loss', verbose=0, save_best_only=True)
callback_list = [checkpointer, earlystopping]

# fit model to the data
history2 = model2.fit(train_padseq, Y_train, 
                     batch_size=128, 
                     epochs=15
                    )

# evalute the model
test_loss2, test_acc2 = model2.evaluate(test_padseq, Y_test, verbose=0)
# Out:
# Epoch 1/15
# 1310/1310 [==============================] - 406s 288ms/step - loss: 1.6588 - accuracy: 0.5460
# Epoch 2/15
# 1310/1310 [==============================] - 365s 279ms/step - loss: 1.1147 - accuracy: 0.6666
# Epoch 3/15
# 1310/1310 [==============================] - 337s 257ms/step - loss: 1.0094 - accuracy: 0.7006
# Epoch 4/15
# 1310/1310 [==============================] - 368s 281ms/step - loss: 0.9364 - accuracy: 0.7246
# Epoch 5/15
# 1310/1310 [==============================] - 383s 292ms/step - loss: 0.8781 - accuracy: 0.7435
# Epoch 6/15
# 1310/1310 [==============================] - 369s 282ms/step - loss: 0.8300 - accuracy: 0.7604
# Epoch 7/15
# 1310/1310 [==============================] - 371s 284ms/step - loss: 0.7865 - accuracy: 0.7763
# Epoch 8/15
# 1310/1310 [==============================] - 395s 301ms/step - loss: 0.7505 - accuracy: 0.7870
# Epoch 9/15
# 1310/1310 [==============================] - 366s 279ms/step - loss: 0.7171 - accuracy: 0.7990
# Epoch 10/15
# 1310/1310 [==============================] - 371s 283ms/step - loss: 0.6897 - accuracy: 0.8086
# Epoch 11/15
# 1310/1310 [==============================] - 374s 286ms/step - loss: 0.6652 - accuracy: 0.8167
# Epoch 12/15
# 1310/1310 [==============================] - 356s 272ms/step - loss: 0.6456 - accuracy: 0.8231
# Epoch 13/15
# 1310/1310 [==============================] - 363s 277ms/step - loss: 0.6252 - accuracy: 0.8290
# Epoch 14/15
# 1310/1310 [==============================] - 364s 278ms/step - loss: 0.6069 - accuracy: 0.8357
# Epoch 15/15
# 1310/1310 [==============================] - 342s 261ms/step - loss: 0.5925 - accuracy: 0.8408
# test loss and accuracy: 3.3136069774627686 0.19854432344436646

# %%
plot_loss_accuracy(history2)

# %%
model2.evaluate(test_padseq, Y_test, verbose=1)
# Out:
# 1310/1310 [==============================] - 22s 16ms/step - loss: 3.3136 - accuracy: 0.1985
# [3.3136069774627686, 0.19854432344436646]

# %%
Y_pred = model2.predict(test_padseq)
Y_pred = np.argmax(Y_pred,axis=1)

Y_test = np.argmax(Y_test,axis=1)

# %%
print(Y_test.shape, Y_pred.shape)
print(Y_test[:5], Y_pred[:5])
# Out:
# (41905,) (41905,)
# [3 2 1 6 4] [0 2 0 6 2]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.09      0.08      0.08      3137
#            1       0.04      0.06      0.05      1342
#            2       0.22      0.32      0.26      8132
#            3       0.17      0.16      0.16      3921
#            4       0.18      0.15      0.16      5643
#            5       0.21      0.14      0.16      4920
#            6       0.33      0.30      0.32      9961
#            7       0.06      0.07      0.06      2447
#            8       0.07      0.05      0.06      2402
#
#     accuracy                           0.20     41905
#    macro avg       0.15      0.15      0.15     41905
# weighted avg       0.20      0.20      0.20     41905

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True);
plt.title('Confusion Matrix', fontsize=20);

# %% [markdown]
# # EXPERIMENT ORDER 5

# %%
# ORDER 5 TRAIN DATA
X_train = X5_train
Y_train = Y5_train

# one hot encoding using keras tokenizer and pad sequencing
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
print("shape of input data: ", X_train.shape)
print("shape of target variable: ", Y_train.shape)

tokenizer = Tokenizer(num_words=1000000, oov_token='<00V>') 
tokenizer.fit_on_texts(X_train) # build the word index
# padding X_train text input data
train_seq = tokenizer.texts_to_sequences(X_train) # converts strinfs into integer lists
train_padseq = pad_sequences(train_seq, maxlen=20) # pads the integer lists to 2D integer tensor 

word_index = tokenizer.word_index
max_words = 15000000  # total number of words to consider in embedding layer
total_words = len(word_index) + 1000
maxlen = 20 # max length of sequence 
Y_train = to_categorical(Y_train, num_classes=9)
print("Length of word index:", total_words)

# %% [markdown]
# ### Model 2, training using Conv1D, Bi-directional RNN, LSTMs and GRU layer

# %%
model2 = Sequential()
model2.add(Embedding(total_words, 100, input_length=maxlen))
model2.add(Bidirectional(LSTM(64, dropout=0.1, recurrent_dropout=0.10, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Bidirectional(SimpleRNN(64, dropout=0.2, recurrent_dropout=0.20, activation='tanh', return_sequences=True)))
model2.add(Conv1D(72, 3, activation='relu'))
model2.add(MaxPooling1D(2))
model2.add(SimpleRNN(64, activation='tanh', dropout=0.2, recurrent_dropout=0.20, return_sequences=True))
model2.add(GRU(64, recurrent_dropout=0.20, recurrent_regularizer='l1_l2'))
model2.add(Dropout(0.2))
model2.add(Dense(9, activation='softmax'))
model2.summary()

# %%
model2.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# SETUP A EARLY STOPPING CALL and model check point API
earlystopping = keras.callbacks.EarlyStopping(monitor='accuracy',
                                              patience=5,
                                              verbose=1,
                                              mode='min'
                                              )
checkpointer = ModelCheckpoint(filepath='bestvalue1',moniter='val_loss', verbose=0, save_best_only=True)
callback_list = [checkpointer, earlystopping]

# fit model to the data
history2 = model2.fit(train_padseq, y_train, 
                     batch_size=128, 
                     epochs=15
                    )

# evalute the model
test_loss2, test_acc2 = model2.evaluate(test_padseq, y_test, verbose=0)
print("test loss and accuracy:", test_loss2, test_acc2)

# %%
plot_loss_accuracy(history2)
