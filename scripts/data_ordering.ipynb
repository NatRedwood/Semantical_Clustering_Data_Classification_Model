# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('C:/Users/natal/CSCI5922_NN/FinalProject/Semantical_Clustering_Data_Classification_Model/data/News_Category_Dataset_v3.json', lines=True)
df.sample(5)
# Out:
#                                                                                                                                      link  \
# 143714                       https://www.huffingtonpost.com/entry/going-granny-embracing-my-inner-grandparent_us_5b9dbe63e4b03a1dcc8c5a43
# 46038   https://www.huffingtonpost.com/entry/theres-a-black-lady-liberty-on-a-us-coin-for-the-first-time-ever_us_5878fd1fe4b0b3c7a7b0e7a4
# 200467                                                  https://www.huffingtonpost.com/entry/creative-process_us_5b9ba620e4b03a1dcc794ef7
# 105393                                        https://www.huffingtonpost.com/entry/the-conundrum-of-corporation-and-nation_b_6830058.html
# 190062                              https://www.huffingtonpost.com/entry/watch-top-youtube-videos-of-the-week_us_5bb3562ce4b0fa920b96a452
#
#                                                                    headline  \
# 143714                         Going Granny: Embracing My Inner Grandparent
# 46038   There's A Black Lady Liberty On A U.S. Coin For The First Time Ever
# 200467                                        Are You Trading Now for Then?
# 105393                              The Conundrum of Corporation and Nation
# 190062                           Watch The Top 9 YouTube Videos Of The Week
#
#             category  \
# 143714     PARENTING
# 46038   BLACK VOICES
# 200467      WELLNESS
# 105393      POLITICS
# 190062          TECH
#
#                                                                                                                                                                                                                                                                                                                                   short_description  \
# 143714                                                                                                                                                                    They get to do fun activities with their children's adorable offspring and then drop them off at home for all the boring, unpleasant stuff like vaccinations and bedtime.
# 46038                                                                                                                                                                                                                                                                                             Lady Liberty is depicted with twists in her hair.
# 200467                                                                                                                                                                                           The anxiety of indecision and indecision of anxiety is far more cumbersome to your spirit than the process of revising, reworking, and rebuilding.
# 105393  Either we lessen the dominance of big American corporations over American politics. Or we increase their allegiance and responsibility to America. It has to be one or the other. Americans can't thrive within a political system run largely by big American corporations -- organized to boost their share prices but not boost America.
# 190062                                                                                                                                                                                                                    If you're looking to see the most popular YouTube videos of the week, look no further. Once again, we're bringing you the
#
#                                                                                                      authors  \
# 143714                                                      Debra Carpenter, Contributor\nMarketing Director
# 46038                                                                                              Zeba Blay
# 200467  Ben Michaelis, Ph.D., Contributor\nClinical psychologist; Author, 'Your Next Big Thing: 10 Small ...
# 105393            Robert Reich, ContributorChancellor's Professor of Public Policy, University of Califor...
# 190062
#
#              date
# 143714 2013-12-30
# 46038  2017-01-13
# 200467 2012-05-04
# 105393 2015-03-09
# 190062 2012-08-25

# %%
# checking if there are no null entries in the data
df.isnull().sum().any()
# Out:
# False

# %%
# plotting the data categories
category_label = df.category.value_counts()
plt.figure(figsize=(15, 8))
sns.set_style('dark')
sns.barplot(category_label.index, category_label)
plt.xlabel('Category', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=70)
plt.title(f'News Categories: {len(df.category.unique())} distinct categories', fontsize=20)
# Out:
# c:\Users\natal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'News Categories: 42 distinct categories')

# %%
# making a df with 4 columns: headline, superclass, class, short-description

# division of classes under superclasses

POLITICS_SUPERCLASS = ['THE WORLDPOST', 'CRIME', 'IMPACT', 'WORLD NEWS', 'WORLDPOST', 'FIFTY', 'GOODNEWS', 'U.S. NEWS']
WELLNESS_SUPERCLASS = ['STYLE & BEAUTY', 'HEALTHY LIVING', 'FOOD & DRINK', 'HOME & LIVING', 'WEDDINGS', '']
